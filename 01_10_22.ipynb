# %% [markdown]
# #Генерация идей
# ###Помощник студента
# ---
# *	Приложение будет использовано студентами для поиска минимальной цены на интересующий продукт в определенном диапазоне
# *	Приложение для мобильных операционных систем iOS и Android
# *	Приложение будет распространяться бесплатно через официальные маркетплейсы платформ. Предполагается монетизация через встроенную рекламу.
# *	Срок вывода продукта на рынок 6 месяцев
#
# ###Интересные места города
# ---
# * Приложение будет использовано туристами, а также людьми, которые желают посетить новое интересное место в своем городе.
# *	Приложение для мобильных операционных систем iOS и Android
# *	Приложение будет распространяться бесплатно через официальные маркетплейсы платформ. Предполагается монетизация через встроенную рекламу.
# *	Срок вывода продукта на рынок 4 месяца
#
# ###Python Roadmap
# ---
# *	Web-сайт будет использован людьми, желающими обучиться языку программирования Python
# *	Web-сайт
# *	Монетизация продукта будет заключаться в платном контенте в самом сайте, а также в виде тематической рекламы.
# *	Срок вывода продукта на рынок 2 месяца
#
# ##Оценка идей
# ---
#
# |  | Иржанова Д | Абуладзе А | Иванов И | Результат |
# ---|------------|------------|----------|-----------|
# Помощник студента | 3| 2 | 2 | 7 |
# Интересные места города| 1 | 2 | 1 | 4 |
# **Python Roadmap** | 2 | 3 | 3 | 8 |

# %% [markdown]
# #Python Roadmap
# ---
# ###Суть:
# Web-сайт, где главное меню отображается в виде дерева графов. На каждой вершине находится определенная ссылка, относящаяся к теме занятия. Пользователь может выбрать интересующую его тему, а также пометить те вершины графа, которые он уже прошел или знает.
# ###Цель:
# Цель нашего проекта облегчить наглядно обучение людей языку программирования Python.
